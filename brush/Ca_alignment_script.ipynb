# %%
import numpy as np
import matplotlib.pyplot as plt
import compress_pickle as pickle
import glob
import os

# %%
dataPath = r'N:\DIRECTION\03_MiceCohorts\06_BJL3_BHJ1\01_ClassicalSessions\BJL3\2PData\Processed\20250131_BJL3_S1\suite2p\plane0'
rawImagingPath = r'N:\#####' ## to be changed

# %%
frameFileNames = glob.glob(rawImagingPath+'/*.tif')
frameFileNames.sort(key=os.path.getmtime())

# %%
F = np.load(dataPath+'/F.npy')

# %%
F.shape
# Out:
# (199, 51439)

# %%
plt.plot(F[4,:])

# %%
sessionData = pickle.load(r"N:\DIRECTION\03_MiceCohorts\06_BJL3_BHJ1\01_ClassicalSessions\BJL3\SessionData\20250131_111448_BJL3_S1_classical.gz")

# %%
sessionData['do_channels']
# Out:
# ['trial_start', 'dir1', 'dir2', 'reward_output', '2P_trigger']

# %%
sessionData['do_data'][0].shape
# Out:
# (5, 139786)

# %%
twoP_trig = sessionData['do_data'][0][-1,:]
twoP_trig2 = sessionData['do_data'][1][-1,:]

# %%
plt.plot(np.concatenate([twoP_trig,twoP_trig2]))
